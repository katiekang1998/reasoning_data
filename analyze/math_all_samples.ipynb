# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
    train_num_correct = (np.concatenate([np.load("../data/MATH_aug/train_aug_1_answer_types5_seed2.npy"), np.load("../data/MATH_aug/train_aug_2_answer_types5_seed2.npy")], axis=0)==0).sum(axis=-1)
    easy_idxs = np.where(train_num_correct>2)[0]
    hard_idxs = np.where(train_num_correct<=2)[0]

# %%
len(easy_idxs)/len(train_num_correct)
# Out:
# 0.42348109102965753

# %%
len(hard_idxs)/len(train_num_correct)
# Out:
# 0.5765189089703424

# %%
train_accs2 = (np.load('../ckpts/math_all_2epochs_llama2/test_answer_types5_seed2.npy')==0).sum(axis=-1)

# %%
plt.hist(train_accs2)
# Out:
# (array([2371.,    0.,  695.,    0.,  486.,    0.,  401.,    0.,  453.,
#          594.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
train_accs2 = (np.load('data/MATH_aug/train_aug_1_answer_types5_seed2.npy')==0).sum(axis=-1)

# %%
train_accs1 = (np.load('data/MATH_aug/train_aug_1_answer_types5_seed1.npy')==0).sum(axis=-1)
train_accs0 = (np.load('data/MATH_aug/train_aug_1_answer_types5_seed0.npy')==0).sum(axis=-1)

# %%
idxs = np.where(train_accs2==5)[0]
plt.hist(np.mean([train_accs1[idxs], train_accs0[idxs]], axis=0), bins=20)
plt.savefig("delete.jpg")

# %%
test_answers = np.load("ckpts/math_all_2epochs/test_answers5.npy")
test_answer_accs = np.load("ckpts/math_all_2epochs/test_answer_types5.npy")==0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_answers = np.load("ckpts/math_all_2epochs/test_answers5.npy")
#       2 test_answer_accs = np.load("ckpts/math_all_2epochs/test_answer_types5.npy")==0
#
# File ~/miniconda3/envs/trlx2/lib/python3.9/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ckpts/math_all_2epochs/test_answers5.npy'

# %%
plt.hist(test_answer_accs.sum(axis=-1), bins = np.array([0, 1, 2, 3, 4, 5, 6])-0.5)
# Out:
# (array([2121.,  649.,  465.,  381.,  488.,  896.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5]),
#  <BarContainer object of 6 artists>)

# %%
(test_answer_accs.sum(axis=-1)==0).sum()/5000*100000
# Out:
# 42420.0
